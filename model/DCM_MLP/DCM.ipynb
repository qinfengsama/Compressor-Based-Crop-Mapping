# %%
import numpy as np
import paddle
from paddle.io import Dataset, DataLoader
from paddle.vision.transforms import Normalize
from sklearn.preprocessing import MinMaxScaler
import os
import matplotlib.pyplot as plt
import random
import copy
from sklearn.metrics import confusion_matrix, accuracy_score, cohen_kappa_score
from paddle import nn
import paddle.nn.functional as F

# %%
def getTrainTest(label, trainNum):
    # 设置随机种子
    random.seed(32)
    testGt = copy.deepcopy(label)
    trainGt = np.zeros(label.shape)
    labelNum = int(max(label.ravel())) + 1
    for lab in range(1, labelNum):
        labIndex = np.where(label == lab)
        randomList = random.sample(range(0, len(labIndex[0])), int(len(labIndex[0])*trainNum))
        for randInt in randomList:
            x = labIndex[0][randInt]
            y = labIndex[1][randInt]
            trainGt[x][y] = lab
            testGt[x][y] = 0
    trainGt = trainGt.astype(int)
    testGt = testGt.astype(int)
    # drawGT(testGt, "test_gt.jpg")
    # drawGT(trainGt, "train_gt.jpg")
    return trainGt, testGt

select_gt = np.load('/home/aistudio/npys/t30uxv/select_gt.npy').astype(int)
select_rs = np.load('/home/aistudio/npys/t30uxv/select_rs.npy')
train_gt , test_gt = getTrainTest(select_gt, 0.05)

# 数据预处理：归一化
def normalize_data(select_rs):
    scaler = MinMaxScaler()
    H, W, C, T = select_rs.shape
    select_rs_reshaped = select_rs.reshape(-1, C)
    select_rs_normalized = scaler.fit_transform(select_rs_reshaped)
    select_rs_normalized = select_rs_normalized.reshape(H, W, C, T)
    return select_rs_normalized, scaler

def remap_labels(gt):
    # 将标签0映射为-1，其他标签减1
    remapped_gt = np.where(gt == 0, -1, gt - 1)
    
    # 计算映射后的唯一标签数量
    unique_labels = np.unique(remapped_gt)
    num_classes = len(unique_labels)
    
    return remapped_gt, num_classes-1


class RSDataset(Dataset):
    def __init__(self, rs_data, gt_data=None):
        # 假设rs_data的原始格式是H*W*C*T
        # 需要先将数据转换为T*C*H*W
        self.rs_data = rs_data.transpose((3, 2, 0, 1))  # 调整为T*C*H*W
        self.gt_data = gt_data
        self.H, self.W = rs_data.shape[:2]

    def __len__(self):
        return self.H * self.W

    def __getitem__(self, idx):
        row = idx // self.W
        col = idx % self.W
        # 对于每个像素点，获取其所有时间点的数据，现在格式为T*C
        sequence = self.rs_data[:, :, row, col].astype('float32')  # 获取T*C序列
        if self.gt_data is not None:
            label = self.gt_data[row, col]
            # 直接返回序列和标签，不对标签值进行特殊处理
            return sequence, label
        else:
            return sequence, np.array([row, col], dtype='float32')


class DCM(nn.Layer):
    def __init__(
        self, seed, input_feature_size, hidden_size, num_layers,
        bidirectional, dropout, num_classes
    ):
        super().__init__()
        self._set_reproducible(seed)

        # 修正：使用`dropout`参数而非`dropout_prob`
        self.lstm = nn.LSTM(
            input_size=input_feature_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            direction='bidirectional' if bidirectional else 'forward',
            dropout=dropout if num_layers > 1 else 0,  # 当num_layers大于1时才设置dropout
            time_major=False
        )  # i/o: (batch, seq_len, num_directions*hidden_size)
        num_directions = 2 if bidirectional else 1
        self.attention = nn.Linear(
            in_features=num_directions * hidden_size,
            out_features=1,
        )
        self.fc = nn.Linear(
            in_features=num_directions * hidden_size,
            out_features=num_classes,
        )

    def _set_reproducible(self, seed, cudnn=False):
        paddle.seed(seed)
        np.random.seed(seed)
        if cudnn:
            paddle.set_flags({'FLAGS_cudnn_deterministic': True})

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        attn_weights = F.softmax(F.relu(self.attention(lstm_out)), axis=1)
        fc_in = paddle.bmm(attn_weights.transpose([0, 2, 1]), lstm_out)
        fc_out = self.fc(fc_in)
        return fc_out.squeeze()


def calculate_metrics(true_labels, predicted_labels):
    """
    计算OA, AA, Kappa和mIoU
    """
    # 整体准确率 OA
    oa = accuracy_score(true_labels, predicted_labels)
    # Kappa 系数
    kappa = cohen_kappa_score(true_labels, predicted_labels)
    # 混淆矩阵
    conf_matrix = confusion_matrix(true_labels, predicted_labels)
    # 每类的准确率
    acc_per_class = conf_matrix.diagonal() / conf_matrix.sum(axis=1)
    # 平均准确率 AA
    aa = np.mean(acc_per_class)
    # 每类的IoU
    iou_per_class = conf_matrix.diagonal() / (conf_matrix.sum(axis=1) + conf_matrix.sum(axis=0) - conf_matrix.diagonal())
    # 平均IoU mIoU
    miou = np.mean(iou_per_class)
    return oa, aa, kappa, miou, acc_per_class  # 确保返回每类的准确率

def evaluate_metrics(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []
    for data, label in data_loader:
        data = paddle.to_tensor(data)
        output = model(data)
        preds = output.argmax(axis=1).numpy()
        valid_idx = label != -1  # 有效索引，即非-1标签
        all_preds.extend(preds[valid_idx].flatten())
        all_labels.extend(label.numpy()[valid_idx].flatten())
    return calculate_metrics(all_labels, all_preds)


best_oa = -1  # 全局变量用于跟踪最佳OA

# 训练和评估模型，同时保存OA最高时的模型参数和指标
def train_and_evaluate(model, train_loader, test_loader, optimizer, loss_fn, epochs, save_path):
    global best_oa
    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        for batch_id, (data, label) in enumerate(train_loader):
            data = paddle.to_tensor(data)
            label = paddle.to_tensor(label, dtype='int64')
            optimizer.clear_grad()
            output = model(data)
            loss = loss_fn(output, label)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.numpy()

        avg_train_loss = total_train_loss / len(train_loader)
        
        oa, aa, kappa, miou, _ = evaluate_metrics(model, test_loader)
        if oa > best_oa:
            best_oa = oa
            best_model_path = os.path.join(save_path, "model_param.pdparams")
            paddle.save(model.state_dict(), best_model_path)
            print(f"Epoch [{epoch+1}/{epochs}]: New best model saved at {best_model_path} with OA: {best_oa:.4f}")


def final_test_evaluation(model, test_loader, save_path):
    best_model_path = os.path.join(save_path, "model_param.pdparams")
    model_state_dict = paddle.load(best_model_path)
    model.set_state_dict(model_state_dict)
    model.eval()

    all_preds = []
    all_labels = []
    with paddle.no_grad():
        for data, label in test_loader:
            data = paddle.to_tensor(data)
            output = model(data)
            preds = output.argmax(axis=1).numpy()
            valid_idx = label.numpy() != -1
            all_preds.extend(preds[valid_idx].flatten())
            all_labels.extend(label.numpy()[valid_idx].flatten())

    oa, aa, kappa, miou, acc_per_class = calculate_metrics(all_labels, all_preds)
    np.save(os.path.join(save_path, "pre_label.npy"), np.array(all_preds))
    
    with open(os.path.join(save_path, "evaluation_metric.txt"), "w") as f:
        f.write(f"OA: {oa*100:.2f}%\n")
        f.write(f"AA: {aa*100:.2f}%\n")
        f.write(f"Kappa: {kappa*100:.2f}%\n")
        f.write(f"mIoU: {miou*100:.2f}%\n")
        for i, acc in enumerate(acc_per_class):
            f.write(f"class{i+1}: {acc*100:.2f}%\n")

# %%
import os

# 数据集和训练比例的列表
datasets = ['t31tfj', 't31tfm', 't31tfm_1', 't32ulu']
train_ratios = [0.5, 0.2, 0.1, 0.05, 0.02, 0.01]

for dataset in datasets:
    select_gt_path = f'/home/aistudio/npys/{dataset}/select_gt.npy'
    select_rs_path = f'/home/aistudio/npys/{dataset}/select_rs.npy'
    select_gt = np.load(select_gt_path).astype(int)
    select_rs = np.load(select_rs_path)

    for train_ratio in train_ratios:
        print(f"Processing dataset {dataset} with train ratio {train_ratio}")
        train_gt, test_gt = getTrainTest(select_gt, train_ratio)
        select_rs_normalized, _ = normalize_data(select_rs)
        train_gt_remapped, num_classes = remap_labels(train_gt)
        test_gt_remapped, _ = remap_labels(test_gt)

        train_dataset = RSDataset(select_rs_normalized, train_gt_remapped)
        test_dataset = RSDataset(select_rs_normalized, test_gt_remapped)
        train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

        model = DCM(seed=313, input_feature_size=select_rs_normalized.shape[2], hidden_size=256, num_layers=2, bidirectional=True, dropout=0.5, num_classes=num_classes)
        optimizer = paddle.optimizer.Adam(learning_rate=1e-3, parameters=model.parameters())
        loss_fn = paddle.nn.CrossEntropyLoss(ignore_index=-1)

        save_path = f'/home/aistudio/DCM/{dataset}/{train_ratio}'
        if not os.path.exists(save_path):
            os.makedirs(save_path)

        best_oa = -1  # 重置最佳OA
        train_and_evaluate(model, train_loader, test_loader, optimizer, loss_fn, 200, save_path)
        final_test_evaluation(model, test_loader, save_path)
# Out:
# Processing dataset t31tfj with train ratio 0.5
# W0311 15:31:32.010833   595 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 12.0, Runtime API Version: 11.8
# W0311 15:31:32.012507   595 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.3789
# Epoch [13/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.6463
# Epoch [14/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9241
# Epoch [15/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9316
# Epoch [16/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9733
# Epoch [19/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9869
# Epoch [23/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9884
# Epoch [26/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9893
# Epoch [35/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9944
# Epoch [40/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9956
# Epoch [64/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9959
# Epoch [77/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9961
# Epoch [83/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9964
# Epoch [88/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9968
# Epoch [150/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9971
# Epoch [189/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.5/model_param.pdparams with OA: 0.9978
# Processing dataset t31tfj with train ratio 0.2
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.3789
# Epoch [40/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.3798
# Epoch [41/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.4247
# Epoch [42/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.4689
# Epoch [44/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.5196
# Epoch [45/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.5237
# Epoch [46/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.5274
# Epoch [73/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.5326
# Epoch [80/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.5617
# Epoch [86/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.5685
# Epoch [91/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.6369
# Epoch [95/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.6386
# Epoch [97/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.6637
# Epoch [98/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.6777
# Epoch [103/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.7235
# Epoch [117/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.7401
# Epoch [134/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.7438
# Epoch [144/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.7515
# Epoch [154/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.7718
# Epoch [177/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.8056
# Epoch [181/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.2/model_param.pdparams with OA: 0.8272
# Processing dataset t31tfj with train ratio 0.1
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.1/model_param.pdparams with OA: 0.3788
# Epoch [85/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.1/model_param.pdparams with OA: 0.4143
# Epoch [91/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.1/model_param.pdparams with OA: 0.5422
# Epoch [176/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.1/model_param.pdparams with OA: 0.5648
# Epoch [186/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.1/model_param.pdparams with OA: 0.5689
# Epoch [188/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.1/model_param.pdparams with OA: 0.5817
# Epoch [190/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.1/model_param.pdparams with OA: 0.6233
# Processing dataset t31tfj with train ratio 0.05
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.05/model_param.pdparams with OA: 0.3788
# Epoch [111/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.05/model_param.pdparams with OA: 0.3791
# Epoch [130/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.05/model_param.pdparams with OA: 0.3902
# Epoch [144/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.05/model_param.pdparams with OA: 0.4480
# Epoch [147/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.05/model_param.pdparams with OA: 0.5335
# Epoch [165/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.05/model_param.pdparams with OA: 0.5739
# Processing dataset t31tfj with train ratio 0.02
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.02/model_param.pdparams with OA: 0.3789
# Processing dataset t31tfj with train ratio 0.01
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfj/0.01/model_param.pdparams with OA: 0.3789
# Processing dataset t31tfm with train ratio 0.5
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.5501
# Epoch [3/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.6455
# Epoch [4/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.7436
# Epoch [5/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9256
# Epoch [6/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9601
# Epoch [9/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9737
# Epoch [12/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9761
# Epoch [14/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9800
# Epoch [21/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9827
# Epoch [24/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9862
# Epoch [25/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9884
# Epoch [32/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9890
# Epoch [38/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9900
# Epoch [47/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9907
# Epoch [53/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9916
# Epoch [54/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9917
# Epoch [72/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9933
# Epoch [106/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.5/model_param.pdparams with OA: 0.9938
# Processing dataset t31tfm with train ratio 0.2
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.4968
# Epoch [2/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.6620
# Epoch [3/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.7533
# Epoch [4/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.7691
# Epoch [5/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.8454
# Epoch [7/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.8854
# Epoch [8/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9324
# Epoch [13/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9513
# Epoch [17/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9577
# Epoch [18/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9650
# Epoch [20/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9700
# Epoch [23/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9737
# Epoch [24/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9802
# Epoch [28/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9831
# Epoch [42/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9839
# Epoch [43/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9882
# Epoch [65/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9909
# Epoch [106/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.2/model_param.pdparams with OA: 0.9917
# Processing dataset t31tfm with train ratio 0.1
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.3558
# Epoch [2/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.5121
# Epoch [5/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.5824
# Epoch [6/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.6398
# Epoch [11/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.6779
# Epoch [14/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.7095
# Epoch [16/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.7880
# Epoch [17/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.8161
# Epoch [18/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.8472
# Epoch [20/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.8874
# Epoch [24/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9324
# Epoch [25/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9440
# Epoch [35/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9644
# Epoch [53/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9647
# Epoch [54/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9697
# Epoch [62/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9736
# Epoch [66/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9777
# Epoch [85/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9805
# Epoch [89/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9809
# Epoch [94/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9821
# Epoch [104/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9822
# Epoch [107/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9824
# Epoch [116/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9838
# Epoch [145/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9846
# Epoch [193/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.1/model_param.pdparams with OA: 0.9847
# Processing dataset t31tfm with train ratio 0.05
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.3558
# Epoch [9/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.3973
# Epoch [10/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.4743
# Epoch [12/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.5447
# Epoch [13/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.6301
# Epoch [14/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.6803
# Epoch [15/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.7277
# Epoch [16/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.7290
# Epoch [17/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.8403
# Epoch [18/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.8439
# Epoch [20/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.8769
# Epoch [21/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9076
# Epoch [27/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9149
# Epoch [28/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9506
# Epoch [29/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9545
# Epoch [34/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9580
# Epoch [36/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9648
# Epoch [44/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9723
# Epoch [77/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9742
# Epoch [83/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9770
# Epoch [191/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.05/model_param.pdparams with OA: 0.9773
# Processing dataset t31tfm with train ratio 0.02
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.3558
# Epoch [16/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.4742
# Epoch [17/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.5033
# Epoch [19/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.6325
# Epoch [21/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.6441
# Epoch [23/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.7172
# Epoch [25/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.7176
# Epoch [26/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.7549
# Epoch [30/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.8218
# Epoch [31/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.8353
# Epoch [106/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.8592
# Epoch [110/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.8850
# Epoch [119/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.8892
# Epoch [124/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.9154
# Epoch [141/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.9303
# Epoch [149/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.9371
# Epoch [167/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.9451
# Epoch [181/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.02/model_param.pdparams with OA: 0.9451
# Processing dataset t31tfm with train ratio 0.01
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.3558
# Epoch [14/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.3578
# Epoch [15/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.4233
# Epoch [16/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.5621
# Epoch [17/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.5760
# Epoch [19/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.6916
# Epoch [73/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.7283
# Epoch [74/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.7298
# Epoch [75/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.7402
# Epoch [76/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.7618
# Epoch [79/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.7998
# Epoch [81/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.8125
# Epoch [85/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.8209
# Epoch [91/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.8242
# Epoch [92/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.8510
# Epoch [101/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.8589
# Epoch [102/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.8714
# Epoch [108/200]: New best model saved at /home/aistudio/DCM/t31tfm/0.01/model_param.pdparams with OA: 0.8949
# Processing dataset t31tfm_1 with train ratio 0.5
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.6892
# Epoch [2/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.8628
# Epoch [3/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.8806
# Epoch [4/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9379
# Epoch [5/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9746
# Epoch [6/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9757
# Epoch [7/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9768
# Epoch [11/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9790
# Epoch [12/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9832
# Epoch [17/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9855
# Epoch [20/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9868
# Epoch [25/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9882
# Epoch [26/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9891
# Epoch [43/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9905
# Epoch [48/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9917
# Epoch [72/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9925
# Epoch [80/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.5/model_param.pdparams with OA: 0.9931
# Processing dataset t31tfm_1 with train ratio 0.2
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.3472
# Epoch [2/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.5295
# Epoch [4/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.7032
# Epoch [6/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9291
# Epoch [7/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9329
# Epoch [8/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9583
# Epoch [11/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9647
# Epoch [12/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9744
# Epoch [14/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9788
# Epoch [18/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9789
# Epoch [22/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9828
# Epoch [23/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9843
# Epoch [34/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9866
# Epoch [49/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9876
# Epoch [68/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9887
# Epoch [87/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9905
# Epoch [104/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.2/model_param.pdparams with OA: 0.9911
# Processing dataset t31tfm_1 with train ratio 0.1
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.3480
# Epoch [2/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.5014
# Epoch [4/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.5266
# Epoch [6/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.5939
# Epoch [13/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.5962
# Epoch [15/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.5968
# Epoch [16/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.6234
# Epoch [22/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.6339
# Epoch [24/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.7180
# Epoch [25/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.8183
# Epoch [27/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9120
# Epoch [31/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9396
# Epoch [32/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9634
# Epoch [36/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9713
# Epoch [58/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9719
# Epoch [72/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9741
# Epoch [74/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9742
# Epoch [77/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9816
# Epoch [109/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9821
# Epoch [115/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9822
# Epoch [118/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9829
# Epoch [148/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9841
# Epoch [160/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.1/model_param.pdparams with OA: 0.9845
# Processing dataset t31tfm_1 with train ratio 0.05
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.2976
# Epoch [2/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.3472
# Epoch [5/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.5755
# Epoch [8/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.6274
# Epoch [9/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.6669
# Epoch [10/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.7477
# Epoch [34/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.7514
# Epoch [36/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.7654
# Epoch [37/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.7691
# Epoch [40/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.7996
# Epoch [43/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.8109
# Epoch [45/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.8184
# Epoch [46/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.8202
# Epoch [47/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.8451
# Epoch [49/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.8561
# Epoch [54/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.8627
# Epoch [57/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.8833
# Epoch [60/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9034
# Epoch [62/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9094
# Epoch [65/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9196
# Epoch [74/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9218
# Epoch [76/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9289
# Epoch [78/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9362
# Epoch [79/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9433
# Epoch [81/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9443
# Epoch [89/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9445
# Epoch [95/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9454
# Epoch [99/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9492
# Epoch [100/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9538
# Epoch [107/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9545
# Epoch [113/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9631
# Epoch [122/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9659
# Epoch [132/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9672
# Epoch [140/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9697
# Epoch [142/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9724
# Epoch [159/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9727
# Epoch [178/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.05/model_param.pdparams with OA: 0.9734
# Processing dataset t31tfm_1 with train ratio 0.02
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.2976
# Epoch [2/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.3472
# Epoch [21/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.3990
# Epoch [24/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.5422
# Epoch [34/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.5690
# Epoch [35/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.5694
# Epoch [47/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.5744
# Epoch [57/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.5921
# Epoch [66/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.6511
# Epoch [71/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.6621
# Epoch [84/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.6624
# Epoch [97/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.6919
# Epoch [114/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.6962
# Epoch [117/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.7016
# Epoch [123/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.7133
# Epoch [128/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.7432
# Epoch [129/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.7954
# Epoch [139/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.8135
# Epoch [142/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.8415
# Epoch [158/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.8465
# Epoch [161/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.02/model_param.pdparams with OA: 0.9199
# Processing dataset t31tfm_1 with train ratio 0.01
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.3472
# Epoch [23/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.3609
# Epoch [24/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.4430
# Epoch [26/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.5489
# Epoch [31/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.5759
# Epoch [56/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.5849
# Epoch [57/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.5882
# Epoch [58/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.6130
# Epoch [60/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.6616
# Epoch [85/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.6663
# Epoch [98/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.6721
# Epoch [101/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.6988
# Epoch [110/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.7082
# Epoch [112/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.7300
# Epoch [115/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.7730
# Epoch [121/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.7988
# Epoch [131/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.8662
# Epoch [143/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.8810
# Epoch [156/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.8866
# Epoch [166/200]: New best model saved at /home/aistudio/DCM/t31tfm_1/0.01/model_param.pdparams with OA: 0.8899
# Processing dataset t32ulu with train ratio 0.5
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.8415
# Epoch [2/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9265
# Epoch [3/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9814
# Epoch [6/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9854
# Epoch [7/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9899
# Epoch [9/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9911
# Epoch [17/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9931
# Epoch [19/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9932
# Epoch [28/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9940
# Epoch [30/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9944
# Epoch [37/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9946
# Epoch [44/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9960
# Epoch [53/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9964
# Epoch [78/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9967
# Epoch [83/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9968
# Epoch [96/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9971
# Epoch [164/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9972
# Epoch [165/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.5/model_param.pdparams with OA: 0.9975
# Processing dataset t32ulu with train ratio 0.2
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.6997
# Epoch [3/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.8307
# Epoch [4/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9535
# Epoch [8/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9796
# Epoch [11/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9818
# Epoch [12/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9833
# Epoch [16/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9854
# Epoch [17/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9887
# Epoch [20/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9894
# Epoch [26/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9901
# Epoch [35/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9913
# Epoch [39/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9925
# Epoch [48/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9926
# Epoch [52/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9929
# Epoch [57/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9936
# Epoch [62/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9939
# Epoch [63/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9944
# Epoch [111/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.2/model_param.pdparams with OA: 0.9944
# Processing dataset t32ulu with train ratio 0.1
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.7935
# Epoch [3/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.8839
# Epoch [4/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9332
# Epoch [5/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9488
# Epoch [6/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9545
# Epoch [7/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9782
# Epoch [8/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9802
# Epoch [11/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9819
# Epoch [12/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9857
# Epoch [14/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9876
# Epoch [22/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9889
# Epoch [30/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9899
# Epoch [31/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9901
# Epoch [42/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9908
# Epoch [44/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9910
# Epoch [48/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9912
# Epoch [61/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9915
# Epoch [67/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9917
# Epoch [101/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9924
# Epoch [131/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.1/model_param.pdparams with OA: 0.9935
# Processing dataset t32ulu with train ratio 0.05
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.6997
# Epoch [6/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.8183
# Epoch [13/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.8271
# Epoch [14/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.8491
# Epoch [22/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.8587
# Epoch [25/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.8846
# Epoch [27/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9011
# Epoch [28/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9185
# Epoch [29/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9233
# Epoch [30/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9619
# Epoch [31/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9655
# Epoch [35/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9775
# Epoch [37/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9842
# Epoch [44/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9846
# Epoch [47/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9869
# Epoch [61/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9872
# Epoch [74/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9884
# Epoch [77/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9886
# Epoch [93/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9887
# Epoch [94/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9890
# Epoch [98/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9895
# Epoch [99/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9897
# Epoch [113/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9899
# Epoch [122/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9913
# Epoch [145/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.05/model_param.pdparams with OA: 0.9921
# Processing dataset t32ulu with train ratio 0.02
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.6997
# Epoch [10/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.8207
# Epoch [11/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.8273
# Epoch [16/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.8417
# Epoch [18/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.8500
# Epoch [46/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.8515
# Epoch [62/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.8529
# Epoch [81/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.8539
# Epoch [84/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.8547
# Epoch [85/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9199
# Epoch [86/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9210
# Epoch [102/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9234
# Epoch [111/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9269
# Epoch [118/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9311
# Epoch [123/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9435
# Epoch [126/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9584
# Epoch [132/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9639
# Epoch [142/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9691
# Epoch [176/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9708
# Epoch [184/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.02/model_param.pdparams with OA: 0.9787
# Processing dataset t32ulu with train ratio 0.01
# Epoch [1/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.6997
# Epoch [16/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.8178
# Epoch [19/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.8284
# Epoch [20/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.8288
# Epoch [21/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.8378
# Epoch [27/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.8672
# Epoch [65/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.9165
# Epoch [132/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.9418
# Epoch [146/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.9534
# Epoch [150/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.9615
# Epoch [162/200]: New best model saved at /home/aistudio/DCM/t32ulu/0.01/model_param.pdparams with OA: 0.9622
